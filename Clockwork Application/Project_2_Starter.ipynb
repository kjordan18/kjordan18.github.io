# %%
# SQL Alchemy
import sqlalchemy
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.engine import reflection

#import egnine
from config import engine_url

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Pandas
import pandas as pd

# %%
engine_url
# Out:
# 'mysql://spmb:appoloodatavag@cw-spmb.ct4csmrmjrt7.us-west-2.rds.amazonaws.com:53306/spmb_101'

# %%
engine = create_engine('mysql://spmb:appoloodatavag@cw-spmb.ct4csmrmjrt7.us-west-2.rds.amazonaws.com:53306/spmb_101')
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     919                                 (self.host, self.port), self.connect_timeout,
# --> 920                                 **kwargs)
#     921                             break
#
# ~/anaconda3/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
date = '%2016%'
type1 = '%Project%'
type2 = '%Candid%'
type3 = '%BulkImportEvent%'
cw_em = '%@clockworkrecruiting.com'
sql_events = """select * from events e
    where e.created_at LIKE %s
    AND e.entity_type = %s OR %s
    AND e.type NOT LIKE %s;"""
events_df = pd.read_sql_query(sql_events, s, params=(date, type1, type2, type3))
# events_df.to_csv('events.csv', sep='\t', encoding='utf-8')
events_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-69bbd0ad9df7> in <module>()
#       8     AND e.entity_type = %s OR %s
#       9     AND e.type NOT LIKE %s;"""
# ---> 10 events_df = pd.read_sql_query(sql_events, s, params=(date, type1, type2, type3))
#      11 # events_df.to_csv('events.csv', sep='\t', encoding='utf-8')
#      12 events_df
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330     return pandas_sql.read_query(
#     331         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 332         parse_dates=parse_dates, chunksize=chunksize)
#     333
#     334
#
# ...
